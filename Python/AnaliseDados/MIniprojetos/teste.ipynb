# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
dados = {
        'nome': ['João', 'Maria', 'marcio', 'sergio', 'matheus', 'joana', 'jose'],
        'idade': [25, 30, 65, 18, 20, 32, 90],
        'Estado': ['SP', 'RJ', 'PA','SP', 'RJ', 'PA', 'AM']
         }
df = pd.DataFrame(data=dados)

df
# Out:
#       nome  idade Estado
# 0     João     25     SP
# 1    Maria     30     RJ
# 2   marcio     65     PA
# 3   sergio     18     SP
# 4  matheus     20     RJ
# 5    joana     32     PA
# 6     jose     90     AM

# %%
barra = plt.bar(x=df['nome'], height=df['idade'])
barra = plt.xlabel('número de pessoas')
barra = plt.ylabel('Idades')
barra = plt.title('Idade de pessoas')
barra
# Out:
# Text(0.5, 1.0, 'Idade de pessoas')

# %%
Linha = plt.plot(df['idade'])
linha = plt.xlabel('número de pessoas')
linha = plt.ylabel('Idades')
linha = plt.title('Idade de pessoas')
Linha
