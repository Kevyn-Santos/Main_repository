# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
Atd1 = pd.read_excel("Atendimentos1112.xlsx", engine="openpyxl")
Atd2 = pd.read_excel("Atendimentos 1712.xlsx", engine="openpyxl")
Atd3 = pd.read_excel("Atendimentos 2312.xlsx", engine="openpyxl", sheet_name="Atendimentos")
# Out:
# C:\Users\kevyn\AppData\Roaming\Python\Python312\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
Atd1.head()
# Out:
#                Solicitante Cargo               Caso Horario de inicio  \
# 0  Vanessa Vitória Pereira    GE           WhatsApp          10:45:00
# 1       Anderson Ferreira     PF             oferta          10:54:00
# 2                 Henrique    PF          Propostas          11:02:00
# 3                  Raphael    PF  Erro de pagamento          11:04:00
# 4          Ricardo Batista    PJ            Estoque          11:18:00
#
#   horario de finalização   Ticket             Solução Tempo de atendimento  \
# 0               10:57:00  1560806         Sustentação             00:12:00
# 1               11:03:00  1560823               Queda             00:09:00
# 2               11:09:00  1560840          Informação             00:07:00
# 3               11:20:00  1560823  Envio de pagamento             00:16:00
# 4               11:24:00  1560865         Improdutivo             00:06:00
#
#   Data de atendimento  00:39:00  Unnamed: 10  Unnamed: 11    PF   PJ   GE  \
# ...

# %%
Atd1Processado = Atd1.drop(Atd1.iloc[0:0, 9:], axis=1)
Atd2Processado = Atd2.drop(Atd2.iloc[0:0, 9:], axis=1)
Atd3Processado = Atd3.drop(Atd3.iloc[0:0, 9:], axis=1)

# %%
dfprincipal = pd.concat([Atd1Processado, Atd2Processado, Atd3Processado], ignore_index= True)
dfprincipal.head()
# Out:
#                Solicitante Cargo               Caso Horario de inicio  \
# 0  Vanessa Vitória Pereira    GE           WhatsApp          10:45:00
# 1       Anderson Ferreira     PF             oferta          10:54:00
# 2                 Henrique    PF          Propostas          11:02:00
# 3                  Raphael    PF  Erro de pagamento          11:04:00
# 4          Ricardo Batista    PJ            Estoque          11:18:00
#
#   horario de finalização   Ticket             Solução Tempo de atendimento  \
# 0               10:57:00  1560806         Sustentação             00:12:00
# 1               11:03:00  1560823               Queda             00:09:00
# 2               11:09:00  1560840          Informação             00:07:00
# 3               11:20:00  1560823  Envio de pagamento             00:16:00
# 4               11:24:00  1560865         Improdutivo             00:06:00
#
#   Data de atendimento
# 0          2024-11-12
# 1          2024-11-12
# 2          2024-11-12
# ...
